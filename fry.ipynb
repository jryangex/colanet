# %%
import fiftyone as fo

# The directory containing the source images
data_path = "E:/coco17/train2017"

# The path to the COCO labels JSON file
labels_path = "E:/coco17/annotations/instances_train2017.json"

# Import the dataset
dataset = fo.Dataset.from_dir(
    dataset_type=fo.types.COCODetectionDataset,
    data_path=data_path,
    labels_path=labels_path,
)
# Out:
#  100% |███████████████| 5000/5000 [17.4s elapsed, 0s remaining, 290.8 samples/s]

# %%
session = fo.launch_app(dataset, port=5151)
session.show()
#session.freeze()
# Out:
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# #focontainer-5770656b-4d56-479b-aef4-4ad2155f878f {
#   position: relative;
#   display: block !important;
# }
# #foactivate-5770656b-4d56-479b-aef4-4ad2155f878f {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-5770656b-4d56-479b-aef4-4ad2155f878f:focus {
#   outline: none;
# }
# #fooverlay-5770656b-4d56-479b-aef4-4ad2155f878f {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
#
# <div id="focontainer-5770656b-4d56-479b-aef4-4ad2155f878f">
#    <div id="fooverlay-5770656b-4d56-479b-aef4-4ad2155f878f" style="display: none;">
#       <button id="foactivate-5770656b-4d56-479b-aef4-4ad2155f878f" >Activate</button>
#    </div>
#    <img src='data:image/png;base64,...' style="width: 100%; max-width: 1556px;"/>
# </div>
#
# <script type="text/javascript">
#    (function() {
#      var container = document.getElementById("focontainer-5770656b-4d56-479b-aef4-4ad2155f878f");
#      var overlay = document.getElementById("fooverlay-5770656b-4d56-479b-aef4-4ad2155f878f");
#      fetch(`http://localhost:5151/notebook?handleId=5770656b-4d56-479b-aef4-4ad2155f878f`)
#      .then((response) => response.json())
#      .then(() => {
#         overlay.addEventListener("click", () => {
#           fetch(`http://localhost:5151/reactivate?handleId=5770656b-4d56-479b-aef4-4ad2155f878f`)
#         });
#         container.addEventListener("mouseenter", () => overlay.style.display = "block");
#         container.addEventListener("mouseleave", () => overlay.style.display = "none");
#      });
#    })();
# </script>
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=true&handleId=5770656b-4d56-479b-aef4-4ad2155f878f"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=true&handleId=8f21d4b8-ca09-4e93-89c4-81f63c91ebdd"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=true&handleId=8f21d4b8-ca09-4e93-89c4-81f63c91ebdd"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
